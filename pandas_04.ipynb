# %%
import pandas as pd

dados = pd.read_csv('athlete_events.csv')

# %%
import matplotlib.pyplot as plt

# hist está no pandas, plt está no matplotlib

# Cria histograma a partir do dataframe
# hist( cluna, qtd_de_barras)
dados.hist(column = 'Age', bins = 10)
# exibe o histograma criado
plt.show()

dados.hist(column = 'Weight', bins = 100)
plt.show()
